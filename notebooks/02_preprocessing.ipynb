# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# Plotting settings
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 10

print("✓ Libraries imported successfully")
# Out:
# ✓ Libraries imported successfully

# %%
pd.set_option("display.max_columns", 31)
pd.set_option("display.precision",2)

# %%
df = pd.read_csv("../data/raw/creditcard.csv")
shape_df = df.shape

# %%
print(df.duplicated().sum())
df_nodup = df.drop_duplicates()
shape_nodup = df_nodup.shape
print(shape_nodup)
print(shape_df)
print(f"There were {shape_df[0] - shape_nodup[0]} duplicates, that have been removed")
# Out:
# 1081
# (283726, 31)
# (284807, 31)
# There were 1081 duplicates, that have been removed

# %%
from sklearn.model_selection import train_test_split
X = df_nodup.drop(columns = ["Class"])
y = df_nodup["Class"]

print(X.shape)
print(y.shape)
# Out:
# (283726, 30)
# (283726,)

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size = 0.2, stratify = y, random_state = 42)

# %%
print(f"X_train : \n {X_train.shape}")
print(f"X_test: \n {X_test.shape}")
print(f"y_train: \n {y_train.shape}\n y_test: \n {y_test.shape}")
# Out:
# X_train :
#  (226980, 30)
# X_test:
#  (56746, 30)
# y_train:
#  (226980,)
#  y_test:
#  (56746,)

# %%
X_train["Hour"] = (X_train["Time"] /3600%24).round()

print(X_train.columns)
X_test["Hour"] = (X_test["Time"] /3600%24)
print(X_test.columns)

X_train.head()
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Hour'],
#       dtype='object')
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Hour'],
#       dtype='object')
#             Time    V1    V2    V3    V4    V5    V6    V7    V8    V9   V10  \
# 226238  144549.0  2.24 -1.72 -2.15 -2.58  0.99  3.57 -1.79  0.86 -1.26  1.57
# 134253   80716.0 -1.32  1.63  0.60 -0.04 -0.40 -0.97  0.21  0.74 -1.27 -0.48
# 186465  127116.0  1.91  0.02 -2.09  0.13  1.16  0.61 -0.02  0.18  0.28 -0.50
# 149493   91342.0  1.81  0.32  0.32  3.88  0.05  1.02 -0.73  0.23  0.68  1.15
# 18461    29522.0  1.36 -1.12  0.55 -1.55 -1.19  0.28 -1.20  0.21 -2.09  1.49
#
#          V11   V12   V13   V14   V15   V16   V17   V18   V19   V20   V21  \
# 226238 -0.24 -0.71  0.36 -0.31  0.29 -0.58  0.38 -0.18 -0.32 -0.32 -0.15
# 134253  1.44  1.76  1.25  0.86 -0.27  0.39 -0.27 -0.34  0.39 -0.07 -0.24
# 186465  1.53  1.04  0.48 -0.69  0.96 -0.28  0.79 -0.16 -0.99 -0.21  0.29
# 149493  1.34 -1.78  2.18  1.24 -2.04  1.34 -0.48  0.82 -1.69 -0.23  0.14
# 18461   1.74  0.01  0.33 -0.04  0.47 -0.66  0.79 -0.64 -0.59 -0.36 -0.34
#
#          V22   V23   V24   V25       V26   V27   V28  Amount  Hour
# 226238 -0.05  0.28  0.68 -0.22 -1.59e-01  0.04 -0.05   32.00  16.0
# 134253 -0.95  0.32  0.52 -0.71 -2.67e-01 -0.02  0.05    6.99  22.0
# 186465  1.10 -0.04 -1.69  0.11  7.76e-03  0.05 -0.05   14.95  11.0
# 149493  0.70  0.17  0.70 -0.21 -1.00e-02 -0.02 -0.04   17.30   1.0
# 18461  -0.64  0.25 -0.34 -0.06 -4.40e-01  0.06  0.01   24.00   8.0

# %%
X_train["is_night"] = np.where((X_train["Hour"]>=0) & (X_train["Hour"] <=6), 1 , 0 )
print(X_train.head(20))
# 277454  0.10  4.58e-03 -0.28  1.48e-01  0.10  1.84e-02   17.99  23.0         0
# 239158 -0.19 -1.04e+00  0.47  2.33e-01 -0.11 -6.90e-02   80.21  18.0         0
# 259212 -0.14  6.33e-01 -0.29 -1.18e-01  0.40  1.86e-01    7.00  20.0         0
# 25136   0.17  3.78e-01  0.17 -4.07e-01  0.02  1.79e-02    7.95   9.0         0
# 199864  0.62  6.87e-01  0.48  6.36e-01  0.26 -1.94e-02   18.96  13.0         0
#
# [20 rows x 32 columns]

# %%
X_train["log_amount"] = np.log1p(X_train["Amount"])

# %%
X_test["log_amount"] = np.log1p(X_test["Amount"])

# %%
from numpy import isnan

# %%
print(X_train.shape)
print(X_test.shape)
print((X_train["Hour"]>24).any() | (X_train["Hour"]<0).any())
print(X_train["log_amount"].isna().any())
print(X_train['is_night'].value_counts())
print(X_train['Hour'].min(), X_train['Hour'].max())
print(X_train['log_amount'].describe())
# Out:
# (226980, 33)
# (56746, 33)
# False
# False
# is_night
# 0    206586
# 1     20394
# Name: count, dtype: int64
# 0.0 24.0
# count    226980.00
# mean          3.16
# std           1.66
# min           0.00
# 25%           1.90
# 50%           3.14
# 75%           4.37
# max           9.89
# Name: log_amount, dtype: float64

# %%
print(y_test.value_counts(normalize = True))
print(y_train.value_counts(normalize = True))
# Out:
# Class
# 0    9.98e-01
# 1    1.67e-03
# Name: proportion, dtype: float64
# Class
# 0    9.98e-01
# 1    1.67e-03
# Name: proportion, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)

# %%
X_test_scaled = scaler.transform(X_test)

# %%
print(X_test.shape)
print(X_train.shape)
print(X_train_scaled.shape)
print(X_test_scaled.shape)
# Out:
# (56746, 33)
# (226980, 33)
# (226980, 33)
# (56746, 33)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns = X_train.columns, index = X_train.index)
X_test_scaled = pd.DataFrame(X_test_scaled, columns = X_test.columns, index = X_test.index)

# %%
print(X_train.head())
X_train_scaled.head()
# Out:
#             Time    V1    V2    V3    V4    V5    V6    V7    V8    V9   V10  \
# 226238  144549.0  2.24 -1.72 -2.15 -2.58  0.99  3.57 -1.79  0.86 -1.26  1.57
# 134253   80716.0 -1.32  1.63  0.60 -0.04 -0.40 -0.97  0.21  0.74 -1.27 -0.48
# 186465  127116.0  1.91  0.02 -2.09  0.13  1.16  0.61 -0.02  0.18  0.28 -0.50
# 149493   91342.0  1.81  0.32  0.32  3.88  0.05  1.02 -0.73  0.23  0.68  1.15
# 18461    29522.0  1.36 -1.12  0.55 -1.55 -1.19  0.28 -1.20  0.21 -2.09  1.49
#
#          V11   V12   V13   V14  ...   V18   V19   V20   V21   V22   V23   V24  \
# 226238 -0.24 -0.71  0.36 -0.31  ... -0.18 -0.32 -0.32 -0.15 -0.05  0.28  0.68
# 134253  1.44  1.76  1.25  0.86  ... -0.34  0.39 -0.07 -0.24 -0.95  0.32  0.52
# 186465  1.53  1.04  0.48 -0.69  ... -0.16 -0.99 -0.21  0.29  1.10 -0.04 -1.69
# 149493  1.34 -1.78  2.18  1.24  ...  0.82 -1.69 -0.23  0.14  0.70  0.17  0.70
# 18461   1.74  0.01  0.33 -0.04  ... -0.64 -0.59 -0.36 -0.34 -0.64  0.25 -0.34
#
#          V25       V26   V27   V28  Amount  Hour  is_night  log_amount
# 226238 -0.22 -1.59e-01  0.04 -0.05   32.00  16.0         0        3.50
# 134253 -0.71 -2.67e-01 -0.02  0.05    6.99  22.0         0        2.08
# 186465  0.11  7.76e-03  0.05 -0.05   14.95  11.0         0        2.77
# 149493 -0.21 -1.00e-02 -0.02 -0.04   17.30   1.0         1        2.91
# 18461  -0.06 -4.40e-01  0.06  0.01   24.00   8.0         0        3.22
#
# [5 rows x 33 columns]
#         Time    V1    V2    V3    V4    V5    V6    V7    V8    V9   V10  \
# 226238  1.05  1.15 -1.04 -1.43 -1.82  0.73  2.70 -1.49  0.74 -1.15  1.46
# 134253 -0.30 -0.68  0.99  0.39 -0.03 -0.30 -0.73  0.18  0.63 -1.16 -0.45
# 186465  0.68  0.98  0.02 -1.39  0.09  0.85  0.46 -0.02  0.15  0.26 -0.46
# 149493 -0.07  0.93  0.20  0.21  2.74  0.03  0.77 -0.61  0.20  0.63  1.07
# 18461  -1.38  0.70 -0.68  0.36 -1.09 -0.88  0.21 -1.00  0.18 -1.91  1.39
#
#          V11   V12   V13   V14  ...   V18   V19   V20   V21   V22   V23   V24  \
# 226238 -0.23 -0.71  0.37 -0.33  ... -0.22 -0.39 -0.43 -0.21 -0.07  0.45  1.13
# 134253  1.41  1.78  1.26  0.91  ... -0.41  0.48 -0.09 -0.33 -1.31  0.52  0.85
# 186465  1.50  1.05  0.48 -0.72  ... -0.19 -1.22 -0.28  0.41  1.51 -0.07 -2.79
# 149493  1.31 -1.79  2.19  1.30  ...  0.98 -2.08 -0.30  0.19  0.97  0.28  1.16
# 18461   1.71  0.01  0.33 -0.05  ... -0.77 -0.73 -0.48 -0.47 -0.88  0.40 -0.57
#
#          V25   V26   V27   V28  Amount  Hour  is_night  log_amount
# 226238 -0.42 -0.33  0.09 -0.16   -0.23  0.25     -0.31        0.21
# 134253 -1.37 -0.55 -0.05  0.15   -0.33  1.27     -0.31       -0.65
# 186465  0.20  0.02  0.11 -0.17   -0.30 -0.61     -0.31       -0.23
# 149493 -0.41 -0.02 -0.05 -0.12   -0.29 -2.31      3.18       -0.15
# 18461  -0.12 -0.91  0.16  0.04   -0.26 -1.12     -0.31        0.04
#
# [5 rows x 33 columns]

# %%
print(X_train_scaled["Amount"].mean(axis = 0))
print(X_train_scaled["Hour"].mean(axis = 0))
# Out:
# 7.48796468384069e-17
# -1.2671940234191935e-16

# %%
print(X_train_scaled["Amount"].std(axis = 0))
print(X_train_scaled["Hour"].std(axis = 0))
# Out:
# 1.000002202844533
# 1.0000022028445332

# %%
print(X_train["Amount"].iloc[0])
print(X_train_scaled["Amount"].iloc[0])
# Out:
# 32.0
# -0.22943372384467148

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE(random_state = 42)

# %%
X_train_smote, y_train_smote = sm.fit_resample(X_train_scaled,y_train)

# %%
print(X_train_smote.shape, y_train_smote.shape)
print(X_train_smote.head())
print(y_train_smote.value_counts())
# Out:
# (453204, 33) (453204,)
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Class, dtype: int64
# Class
# 0    226602
# 1    226602
# Name: count, dtype: int64

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
rus = RandomUnderSampler(random_state = 42)

# %%
X_train_under, y_train_under = rus.fit_resample(X_train_scaled, y_train)

# %%
print(y_train.value_counts())
print(X_train_under.shape, y_train_under.shape)
print(X_train_under.head())
print(y_train_under.value_counts())
# Out:
# Class
# 0    226602
# 1       378
# Name: count, dtype: int64
# (756, 33) (756,)
#         Time    V1        V2    V3    V4    V5    V6    V7    V8        V9  \
# 227442  1.06  1.05  4.57e-02 -1.21  0.17  0.42 -0.30  0.04 -0.04  2.91e-01
# 218717  0.98  0.99 -7.45e-01 -0.29 -0.49 -0.97 -0.64 -0.64 -0.17  7.03e-03
# 76902  -0.80 -1.01  7.73e-01  0.81  0.22 -0.94  0.12 -0.83  1.21 -2.14e-01
# 86663  -0.71 -0.63  7.08e-04 -0.09 -0.92 -0.27 -1.52  0.20  0.07 -1.21e+00
# 167195  0.50  0.98 -1.16e-01 -0.19  1.13 -0.35 -0.23 -0.23  0.02  1.15e+00
#
#              V10   V11   V12   V13   V14  ...   V18   V19   V20   V21   V22  \
# 227442 -1.82e-01  0.78  0.53 -0.38 -0.61  ...  0.40  0.56 -0.21 -0.47 -1.27
# 218717  6.05e-01 -0.62 -0.14  0.68 -0.53  ... -1.86  0.71  0.29  0.04 -0.18
# 76902  -1.16e+00 -0.92  1.24  1.19  0.22  ... -0.64 -0.26 -0.50  0.26  0.42
# 86663   5.17e-01 -0.62 -0.07  0.16  0.52  ...  0.82 -1.77 -0.43 -0.30 -0.32
# 167195 -1.40e-03 -1.32  0.47 -0.76 -0.16  ... -1.09  0.17 -0.43 -0.72 -1.70
#
#          V23   V24   V25   V26   V27   V28  Amount  Hour  is_night  log_amount
# 227442  0.47  0.29 -0.50  0.36 -0.18 -0.14   -0.35  0.25     -0.31       -1.25
# 218717  0.45  0.06 -1.01 -1.04 -0.02 -0.06    0.14  0.08     -0.31        1.01
# 76902  -0.09  0.26 -0.56  0.57 -1.18 -0.41   -0.25  0.25     -0.31        0.12
# 86663   0.25  1.23 -1.89  1.50  1.00  0.66   -0.16  0.42     -0.31        0.47
# 167195  0.72 -0.19 -0.68 -2.29  0.13 -0.10   -0.31 -0.95     -0.31       -0.33
#
# [5 rows x 33 columns]
# Class
# 0    378
# 1    378
# Name: count, dtype: int64

# %%
from imblearn.pipeline import Pipeline

# %%
pipeline = Pipeline([
    ('smote', SMOTE(sampling_strategy=0.5, random_state=42)),
    ('under', RandomUnderSampler(sampling_strategy=1.0, random_state=42))
])
X_train_combined, y_train_combined = pipeline.fit_resample(X_train_scaled, y_train)

# %%
print(X_train_combined.shape, y_train_combined.shape)
# Out:
# (226602, 33) (226602,)

# %%
print(y_train_combined.value_counts())
# Out:
# Class
# 0    113301
# 1    113301
# Name: count, dtype: int64

# %%
print(X_train_scaled.shape,y_train.shape)
print(X_train_smote.shape, y_train_smote.shape)
print(X_train_under.shape, y_train_under.shape)
print(X_train_combined.shape, y_train_combined.shape)
# Out:
# (226980, 33) (226980,)
# (453204, 33) (453204,)
# (756, 33) (756,)
# (226602, 33) (226602,)

# %%
print(y_train.value_counts())
print(y_train_smote.value_counts())
print(y_train_under.value_counts())
print(y_train_combined.value_counts())
# Out:
# Class
# 0    226602
# 1       378
# Name: count, dtype: int64
# Class
# 0    226602
# 1    226602
# Name: count, dtype: int64
# Class
# 0    378
# 1    378
# Name: count, dtype: int64
# Class
# 0    113301
# 1    113301
# Name: count, dtype: int64
